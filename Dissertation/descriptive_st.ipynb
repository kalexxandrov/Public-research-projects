# %% [markdown]
# # **Вводные**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel("data5.xlsx", sheet_name=1, index_col='state_name', na_values='..')

# оставляем страны, по которым есть полные данные с 2003 по 2022
df = df.groupby('state_name').filter(lambda x: x['year'].min() <= 2002 and x['year'].max() >= 2022)

# удаляем чрезмерно экономически развитые страны (выбросы)
df = df.drop(['Bahrain', 'Kuwait', 'Oman', 'Qatar', 'Saudi Arabia', 'Trinidad and Tobago', 
              'United Arab Emirates', 'Chile', 'Croatia', 'Hungary', 'Poland', 'Uruguay', 'Equatorial Guinea'])

# удаляем Океанию
df = df[df['region'] != 7]

# выносим названия некоторых колонок в отдельный список для последующих манипуляций
cols = ['libdem_norm_diff', 'property_rights_diff', 'tax_burden_diff', 'government_spending_diff', 
        'business_freedom_diff', 'monetary_freedom_diff', 'trade_freedom_diff', 'investment_freedom_diff', 
        'financial_freedom_diff', 'gov_effectiveness_diff', 'corruption_diff', 'pstab_diff']

cols_1 = ['libdem_norm', 'property_rights', 'tax_burden', 'government_spending', 
        'business_freedom', 'monetary_freedom', 'trade_freedom', 'investment_freedom', 
        'financial_freedom', 'gov_effectiveness', 'corruption', 'pstab']

# %% [markdown]
# # **Оценки распределения по переменным в целом**

# %%
print(df['libdem_norm'].describe().round(2))

sns.histplot(df['libdem_norm'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       39.29
# std        22.91
# min         1.51
# 25%        18.14
# 50%        38.72
# 75%        56.74
# max       100.00
# Name: libdem_norm, dtype: float64

# %%
sns.boxplot(df['libdem_norm'])
plt.show()

# %%
print(df['libdem_norm_diff'].describe().round(2))

sns.histplot(df['libdem_norm_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean       -0.10
# std         4.00
# min       -27.79
# 25%        -0.81
# 50%         0.00
# 75%         0.47
# max        46.16
# Name: libdem_norm_diff, dtype: float64

# %%
sns.boxplot(df['libdem_norm_diff'])
plt.show()

# %%
print(df['property_rights'].describe().round(2))

sns.histplot(df['property_rights'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       37.44
# std        15.15
# min         0.00
# 25%        30.00
# 50%        33.40
# 75%        50.00
# max        86.50
# Name: property_rights, dtype: float64

# %%
sns.boxplot(df['property_rights'])
plt.show()

# %%
print(df['property_rights_diff'].describe().round(2))

sns.histplot(df['property_rights_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean        0.31
# std         5.88
# min       -40.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max        35.50
# Name: property_rights_diff, dtype: float64

# %%
sns.boxplot(df['property_rights_diff'])
plt.show()

# %%
print(df['tax_burden'].describe().round(2))

sns.histplot(df['tax_burden'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       77.84
# std         9.57
# min        40.90
# 25%        72.25
# 50%        79.00
# 75%        84.60
# max        97.60
# Name: tax_burden, dtype: float64

# %%
sns.boxplot(df['tax_burden'])
plt.show()

# %%
print(df['tax_burden_diff'].describe().round(2))

sns.histplot(df['tax_burden_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean        0.44
# std         3.06
# min       -19.10
# 25%        -0.33
# 50%         0.00
# 75%         0.60
# max        25.70
# Name: tax_burden_diff, dtype: float64

# %%
sns.boxplot(df['tax_burden_diff'])
plt.show()

# %%
print(df['government_spending'].describe().round(2))

sns.histplot(df['government_spending'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       75.17
# std        16.14
# min         0.00
# 25%        67.65
# 50%        78.50
# 75%        87.40
# max        98.70
# Name: government_spending, dtype: float64

# %%
sns.boxplot(df['government_spending'])
plt.show()

# %%
print(df['government_spending_diff'].describe().round(2))

sns.histplot(df['government_spending_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean       -0.01
# std         5.88
# min       -39.20
# 25%        -2.10
# 50%         0.00
# 75%         1.90
# max        42.70
# Name: government_spending_diff, dtype: float64

# %%
sns.boxplot(df['government_spending_diff'])
plt.show()

# %%
print(df['business_freedom'].describe().round(2))

sns.histplot(df['business_freedom'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       59.17
# std        12.89
# min        20.00
# 25%        53.30
# 50%        58.80
# 75%        69.15
# max        93.50
# Name: business_freedom, dtype: float64

# %%
sns.boxplot(df['business_freedom'])
plt.show()

# %%
print(df['business_freedom_diff'].describe().round(2))

sns.histplot(df['business_freedom_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean       -0.06
# std         5.12
# min       -34.70
# 25%        -1.40
# 50%         0.00
# 75%         1.30
# max        27.00
# Name: business_freedom_diff, dtype: float64

# %%
sns.boxplot(df['business_freedom_diff'])
plt.show()

# %%
print(df['monetary_freedom'].describe().round(2))

sns.histplot(df['monetary_freedom'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       72.86
# std        11.24
# min         0.00
# 25%        69.60
# 50%        74.90
# 75%        79.00
# max        94.30
# Name: monetary_freedom, dtype: float64

# %%
sns.boxplot(df['monetary_freedom'])
plt.show()

# %%
print(df['monetary_freedom_diff'].describe().round(2))

sns.histplot(df['monetary_freedom_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean       -0.02
# std         4.65
# min       -62.80
# 25%        -1.90
# 50%         0.20
# 75%         2.00
# max        73.00
# Name: monetary_freedom_diff, dtype: float64

# %%
sns.boxplot(df['monetary_freedom_diff'])
plt.show()

# %%
print(df['trade_freedom'].describe().round(2))

sns.histplot(df['trade_freedom'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       69.65
# std        11.46
# min         0.00
# 25%        62.80
# 50%        70.80
# 75%        77.80
# max        89.40
# Name: trade_freedom, dtype: float64

# %%
sns.boxplot(df['trade_freedom'])
plt.show()

# %%
print(df['trade_freedom_diff'].describe().round(2))

sns.histplot(df['trade_freedom_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean        0.32
# std         5.95
# min       -55.90
# 25%        -1.00
# 50%         0.00
# 75%         1.60
# max        52.20
# Name: trade_freedom_diff, dtype: float64

# %%
sns.boxplot(df['trade_freedom_diff'])
plt.show()

# %%
print(df['investment_freedom'].describe().round(2))

sns.histplot(df['investment_freedom'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       49.06
# std        18.84
# min         0.00
# 25%        35.00
# 50%        50.00
# 75%        65.00
# max        90.00
# Name: investment_freedom, dtype: float64

# %%
sns.boxplot(df['investment_freedom'])
plt.show()

# %%
print(df['investment_freedom_diff'].describe().round(2))

sns.histplot(df['investment_freedom_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean        0.07
# std         5.97
# min       -40.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max        35.00
# Name: investment_freedom_diff, dtype: float64

# %%
sns.boxplot(df['investment_freedom_diff'])
plt.show()

# %%
print(df['financial_freedom'].describe().round(2))

sns.histplot(df['financial_freedom'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       46.17
# std        15.80
# min        10.00
# 25%        35.00
# 50%        50.00
# 75%        60.00
# max        90.00
# Name: financial_freedom, dtype: float64

# %%
sns.boxplot(df['financial_freedom'])
plt.show()

# %%
print(df['financial_freedom_diff'].describe().round(2))

sns.histplot(df['financial_freedom_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean        0.03
# std         5.25
# min       -40.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max        40.00
# Name: financial_freedom_diff, dtype: float64

# %%
sns.boxplot(df['financial_freedom_diff'])
plt.show()

# %%
print(df['gov_effectiveness'].describe().round(2))

sns.histplot(df['gov_effectiveness'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       36.67
# std        18.55
# min         0.94
# 25%        22.30
# 50%        36.02
# 75%        51.19
# max        85.44
# Name: gov_effectiveness, dtype: float64

# %%
sns.boxplot(df['gov_effectiveness'])
plt.show()

# %%
print(df['gov_effectiveness_diff'].describe().round(2))

sns.histplot(df['gov_effectiveness_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean        0.00
# std         4.49
# min       -26.67
# 25%        -2.38
# 50%         0.00
# 75%         2.38
# max        22.16
# Name: gov_effectiveness_diff, dtype: float64

# %%
sns.boxplot(df['gov_effectiveness_diff'])
plt.show()

# %%
print(df['corruption'].describe().round(2))

sns.histplot(df['corruption'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       34.55
# std        19.05
# min         0.00
# 25%        19.52
# 50%        32.86
# 75%        47.61
# max        89.10
# Name: corruption, dtype: float64

# %%
sns.boxplot(df['corruption'])
plt.show()

# %%
print(df['corruption_diff'].describe().round(2))

sns.histplot(df['corruption_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean        0.00
# std         4.23
# min       -16.88
# 25%        -2.16
# 50%        -0.00
# 75%         2.23
# max        26.98
# Name: corruption_diff, dtype: float64

# %%
sns.boxplot(df['corruption_diff'])
plt.show()

# %%
print(df['pstab'].describe().round(2))

sns.histplot(df['pstab'], kde=True)
plt.show()
# Out:
# count    1827.00
# mean       32.78
# std        19.53
# min         0.47
# 25%        16.67
# 50%        30.66
# 75%        46.17
# max        93.75
# Name: pstab, dtype: float64

# %%
sns.boxplot(df['pstab'])
plt.show()

# %%
print(df['pstab_diff'].describe().round(2))

sns.histplot(df['pstab_diff'], kde=True)
plt.show()
# Out:
# count    1740.00
# mean       -0.15
# std         5.73
# min       -41.51
# 25%        -2.85
# 50%         0.00
# 75%         2.84
# max        26.65
# Name: pstab_diff, dtype: float64

# %%
sns.boxplot(df['pstab_diff'])
plt.show()

# %% [markdown]
# # **Оценки распределения по группам**

# %%
df_12_plus = df[df.groupby('state_name')['imf_pr'].transform('sum') >= 11]

df_4_to_11 = df[(df.groupby('state_name')['imf_pr'].transform('sum') >= 5) & (df.groupby('state_name')['imf_pr'].transform('sum') <= 10)]

df_3_minus = df[df.groupby('state_name')['imf_pr'].transform('sum') <= 4]

# %%
for col in cols_1:
    print('12+ лет:')
    print(df_12_plus[col].describe())
    print()
    print('От 4 до 11 лет:')
    print(df_4_to_11[col].describe())
    print()
    print('Меньше 3 лет:')
    print(df_3_minus[col].describe())
    print()
    print('12+ лет:')
    sns.histplot(df_12_plus[col])
    plt.show()
    print()
    print('От 4 до 11 лет:')
    sns.histplot(df_4_to_11[col])
    plt.show()
    print('Меньше 3 лет:')
    sns.histplot(df_3_minus[col])
    plt.show()
# Out:
# 12+ лет:
# count    630.000000
# mean      35.522333
# std       17.045961
# min        3.023256
# 25%       22.093023
# 50%       34.476744
# 75%       47.441860
# max       77.674419
# Name: libdem_norm, dtype: float64
#
# От 4 до 11 лет:
# count    630.000000
# mean      43.703581
# std       21.906257
# min        3.372093
# 25%       25.755814
# 50%       45.523256
# 75%       61.250000
# max       83.488372
# Name: libdem_norm, dtype: float64
#
# Меньше 3 лет:
# count    567.000000
# mean      38.570813
# std       28.261426
# min        1.511628
# 25%       13.255814
# 50%       26.976744
# 75%       63.953488
# max      100.000000
# Name: libdem_norm, dtype: float64
#
# 12+ лет:
# От 4 до 11 лет:
# Меньше 3 лет:
# 12+ лет:
# count    630.000000
# mean      36.115873
# std       13.838045
# min        7.100000
# 25%       30.000000
# 50%       30.000000
# 75%       47.675000
# max       81.000000
# Name: property_rights, dtype: float64
#
# От 4 до 11 лет:
# ...

# %%
for col in cols:
    print('12+ лет:')
    print(df_12_plus[col].describe())
    print()
    print('От 4 до 11 лет:')
    print(df_4_to_11[col].describe())
    print()
    print('Меньше 3 лет:')
    print(df_3_minus[col].describe())
    print()
    print('12+ лет:')
    sns.histplot(df_12_plus[col])
    plt.show()
    print()
    print('От 4 до 11 лет:')
    sns.histplot(df_4_to_11[col])
    plt.show()
    print('Меньше 3 лет:')
    sns.histplot(df_3_minus[col])
    plt.show()
# Out:
# 12+ лет:
# count    600.000000
# mean       0.197481
# std        4.665536
# min      -24.302326
# 25%       -0.813953
# 50%        0.000000
# 75%        0.930233
# max       32.906977
# Name: libdem_norm_diff, dtype: float64
#
# От 4 до 11 лет:
# count    600.000000
# mean      -0.144574
# std        4.140783
# min      -27.558140
# 25%       -0.930233
# 50%        0.000000
# 75%        0.465116
# max       46.162791
# Name: libdem_norm_diff, dtype: float64
#
# Меньше 3 лет:
# count    540.000000
# mean      -0.379414
# std        2.877582
# min      -27.790698
# 25%       -0.581395
# 50%        0.000000
# 75%        0.232558
# max       18.837209
# Name: libdem_norm_diff, dtype: float64
#
# 12+ лет:
# От 4 до 11 лет:
# Меньше 3 лет:
# 12+ лет:
# count    600.000000
# mean       0.200333
# std        5.517279
# min      -20.900000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       35.500000
# Name: property_rights_diff, dtype: float64
#
# От 4 до 11 лет:
# ...

# %% [markdown]
# # **Страны и регионы**

# %%
states = df.groupby('state_name')['imf_pr'].agg('sum')
states_11_and_more = states[states >= 11]

print('Список стран, учавствовавших в программах МВФ более 11 лет:')
print(states_11_and_more.index.tolist())
print(f'Кол-во: {len(states_11_and_more.index.tolist())}.')
print()

states_5_to_10 = states[(states >= 5) & (states <= 10)]

print('Список стран, учавствовавших в программах МВФ от 5 до 10 лет (включительно):')
print(states_5_to_10.index.tolist())
print(f'Кол-во: {len(states_5_to_10.index.tolist())}.')
print()

states_4_and_less = states[states <= 4]

print('Список стран, учавствовавших в программах МВФ 4 и менее лет:')
print(states_4_and_less.index.tolist())
print(f'Кол-во: {len(states_4_and_less.index.tolist())}.')
# Out:
# Список стран, учавствовавших в программах МВФ более 11 лет:
# ['Albania', 'Armenia', 'Benin', 'Bosnia and Herzegovina', 'Burkina Faso', 'Cameroon', 'Central African Republic', 'Chad', 'Congo', "Côte d'Ivoire", 'Gambia', 'Georgia', 'Ghana', 'Guinea', 'Haiti', 'Honduras', 'Jordan', 'Kenya', 'Kyrgyzstan', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Moldova', 'Niger', 'Pakistan', 'Romania', 'Sri Lanka', 'Ukraine', 'Zambia']
# Кол-во: 30.
#
# Список стран, учавствовавших в программах МВФ от 5 до 10 лет (включительно):
# ['Argentina', 'Bangladesh', 'Bolivia', 'Bulgaria', 'Cabo Verde', 'Colombia', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Ethiopia', 'Guatemala', 'Guyana', 'Jamaica', 'Lesotho', 'Mongolia', 'Mozambique', 'Nepal', 'Nicaragua', 'North Macedonia', 'Paraguay', 'Peru', 'Rwanda', 'Senegal', 'Tajikistan', 'Tanzania', 'Togo', 'Tunisia', 'Türkiye', 'Uganda']
# Кол-во: 30.
#
# Список стран, учавствовавших в программах МВФ 4 и менее лет:
# ...

# %%
states_11_plus = df[df.groupby('state_name')['imf_pr'].transform('sum') >= 11].groupby('state_name')['region'].agg('mean')
states_5_to_10 = df[(df.groupby('state_name')['imf_pr'].transform('sum') >= 5) & (df.groupby('state_name')['imf_pr'].transform('sum') <= 10)].groupby('state_name')['region'].agg('mean')
states_4_minus = df[df.groupby('state_name')['imf_pr'].transform('sum') <= 4].groupby('state_name')['region'].agg('mean')

# %%
region_sum = states_4_minus.value_counts().sort_index()

sns.set_style('darkgrid')
ax = sns.barplot(x=region_sum.index, y=region_sum.values, color='lightgreen', edgecolor='grey')
ax.set_xticks(range(len(region_sum.index)))
ax.set_xticklabels(['LACB', 'S-S Africa', 'Middle East', 'Post-USSR', 'South Asia and ATR'], rotation=10)
plt.yticks([0, 4, 8, 12, 16, 20])
plt.title('Распределение стран по регионам (11+ лет в программах МВФ)')
plt.ylabel('count')
plt.show()

# %%
region_sum = states_5_to_10.value_counts().sort_index()

sns.set_style('darkgrid')
ax = sns.barplot(x=region_sum.index, y=region_sum.values, color='lightgreen', edgecolor='grey')
ax.set_xticks(range(len(region_sum)))
ax.set_xticklabels(['LACB', 'S-S Africa', 'Middle East', 'Europe', 'Post-USSR', 'South Asia and ATR'], rotation=10)
plt.title('Распределение стран по регионам (От 5 до 10 лет в программах МВФ)')
plt.ylabel('count')
plt.show()

# %%
region_sum = states_11_plus.value_counts().sort_index()

sns.set_style('darkgrid')
ax = sns.barplot(x=region_sum.index, y=region_sum.values, color='lightgreen', edgecolor='grey')
ax.set_xticks(range(len(region_sum.index)))
ax.set_xticklabels(['LACB', 'S-S Africa', 'Middle East', 'Europe', 'Post-USSR', 'South Asia and ATR'], rotation=10)
plt.yticks([0, 4, 8, 12, 16, 20])
plt.title('Распределение стран по регионам (11+ лет в программах МВФ)')
plt.ylabel('count')
plt.show()
